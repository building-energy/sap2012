# %% [markdown]
# # changing_inputs
#
# This Notebook loads an input file, changes the inputs and for each change runs the sap2012 model.

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
import sap2012
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import seaborn as sns
s=sap2012.Sap2012()

# %% [markdown]
# ## Read input file

# %%
fp='input_csv_file_low_ins.csv'
s.read_input_csv(fp)

# %% [markdown]
# Here this is changed to the three possible options below:

# %%
s.inputs['window_u_value']
# Out:
# 4.8

# %% [markdown]
# # list inputs to adjust values

# %%
index_name = ['assumed_occupancy', 'temperature_during_heating_living_room'
             ,'hours_heating_is_off_1_weekday_living_room','hours_heating_is_off_2_weekday_living_room'
             ,'hours_heating_is_off_1_weekend_living_room','hours_heating_is_off_2_weekend_living_room','hours_heating_is_off_1_weekday_rest_of_dwelling','hours_heating_is_off_2_weekday_rest_of_dwelling'
             ,'hours_heating_is_off_1_weekend_rest_of_dwelling','hours_heating_is_off_2_weekend_rest_of_dwelling']

# %%
#sample = random.sample(index_name,len(index_name))
#sample

# %% [markdown]
# # Generate list of input values for each variable

# %%
values = []
for i in range(len(index_name)):
    values.append(s.inputs[index_name[i]])
values
# Out:
# [2.73, 21.0, 7.0, 8.0, 0.0, 8.0, 7.0, 8.0, 0.0, 8.0]

# %%
value_min = []
for i in range(len(index_name)):
    if (type(values[i])==list):
        calc_list_min = np.array(values[i])
        value_min.append(calc_list_min - 0.01 * calc_list_min)
    else:
        value_min.append(values[i] - 0.01 * values[i])

value_min
# Out:
# [2.7027, 20.79, 6.93, 7.92, 0.0, 7.92, 6.93, 7.92, 0.0, 7.92]

# %%
value_max = []
for i in range(len(index_name)):
    if (type(values[i])==list):
        calc_list_max = np.array(values[i])
        value_max.append(calc_list_max + 0.01 * calc_list_max)
    else:
        value_max.append(values[i] + 0.01 * values[i])

value_max
# Out:
# [2.7573, 21.21, 7.07, 8.08, 0.0, 8.08, 7.07, 8.08, 0.0, 8.08]

# %%
runs = 4

# %%
print (type(s.inputs['area']))
# Out:
# <class 'list'>

# %%
print(s.inputs['area'])
# Out:
# [0, 49.95, 48.99]

# %% [raw]
# my_list = s.inputs['area']

# %%
my_list = s.inputs['area']

# %%
my_list
# Out:
# [0, 49.95, 48.99]

# %% [markdown]
# # Rearrange values to

# %%
my_list_2 = np.array(s.inputs['area'])

# %%
my_list_2 * 5
# Out:
# array([  0.  , 249.75, 244.95])

# %% [markdown]
# For each variable, the SAP model is run and the results stored in the `outputs` dictionary:

# %%
outputs={} 
total_energy_used_table = {}
for k in range(100):
    value_min = []
    value_max = []
    values = []
    for i in range(len(index_name)):
        values.append(s.inputs[index_name[i]])
        if (type(values[i])==list):
            calc_list_min = np.array(values[i])
            value_min.append(calc_list_min - 0.1 * calc_list_min)
            calc_list_max = np.array(values[i])
            value_max.append(calc_list_max + 0.1 * calc_list_max)
        else:
            value_min.append(values[i] - 0.1 * values[i])
            value_max.append(values[i] + 0.1 * values[i])
        s.inputs[index_name[i]] = random.uniform(value_min[i],value_max[i])
        
    s.run()
    total_energy_used = ([v['total_energy_used'] for v in outputs.values()])
    total_energy_used_table[k]=total_energy_used
    outputs['run%s' % str(k+1)]=s.outputs.copy()# needs copy otherwise the same object is placed in all dictionary items
    s.read_input_csv(fp)  
    output_table = pd.DataFrame(outputs)

# %% [markdown]
# Plot results

# %%
output_table
# Out:
#                                                                                            run1  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7648.72
# dwelling_CO2_emission_rate                                                              77.3067
# CF                                                                                      53.1383
# EI_rating                                                                               36.0863
#
#                                                                                            run2  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7204.68
# dwelling_CO2_emission_rate                                                              72.8187
# CF                                                                                      50.0534
# EI_rating                                                                               38.5538
#
#                                                                                            run3  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6961.14
# dwelling_CO2_emission_rate                                                              70.3572
# CF                                                                                      48.3614
# EI_rating                                                                               39.9726
#
#                                                                                            run4  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                               8468.1
# dwelling_CO2_emission_rate                                                              85.5882
# CF                                                                                      58.8308
# EI_rating                                                                               31.8876
#
#                                                                                            run5  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6659.19
# dwelling_CO2_emission_rate                                                              67.3054
# CF                                                                                      46.2637
# EI_rating                                                                               41.8022
#
#                                                                                            run6  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7099.83
# dwelling_CO2_emission_rate                                                               71.759
# CF                                                                                      49.3249
# EI_rating                                                                               39.1587
#
#                                                                                            run7  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6551.19
# dwelling_CO2_emission_rate                                                              66.2138
# CF                                                                                      45.5133
# EI_rating                                                                               42.4768
#
#                                                                                            run8  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8221.79
# dwelling_CO2_emission_rate                                                              83.0988
# CF                                                                                      57.1196
# EI_rating                                                                               33.1054
#
#                                                                                            run9  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7529.19
# dwelling_CO2_emission_rate                                                              76.0985
# CF                                                                                      52.3078
# EI_rating                                                                               36.7362
#
#                                                                                           run10  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7233.29
# dwelling_CO2_emission_rate                                                              73.1079
# CF                                                                                      50.2521
# EI_rating                                                                               38.3903
#
#                                                     ...  \
# volume                                              ...
# total_floor_area                                    ...
# dwelling_volume                                     ...
# number_of_chimneys_total                            ...
# number_of_chimneys_m3_per_hour                      ...
# ...                                                 ...
# energy_saving_generation_technologies_total_emi...  ...
# total_CO2_emissions_yearly                          ...
# dwelling_CO2_emission_rate                          ...
# CF                                                  ...
# EI_rating                                           ...
#
#                                                                                           run91  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7558.63
# dwelling_CO2_emission_rate                                                              76.3961
# CF                                                                                      52.5124
# EI_rating                                                                               36.5752
#
#                                                                                           run92  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8747.12
# dwelling_CO2_emission_rate                                                              88.4083
# CF                                                                                      60.7692
# EI_rating                                                                               30.5501
#
#                                                                                           run93  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                               7690.4
# dwelling_CO2_emission_rate                                                              77.7279
# CF                                                                                      53.4278
# EI_rating                                                                               35.8621
#
#                                                                                           run94  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                               7904.6
# dwelling_CO2_emission_rate                                                              79.8929
# CF                                                                                      54.9159
# EI_rating                                                                               34.7286
#
#                                                                                           run95  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7521.15
# dwelling_CO2_emission_rate                                                              76.0173
# CF                                                                                       52.252
# EI_rating                                                                               36.7802
#
#                                                                                           run96  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8392.31
# dwelling_CO2_emission_rate                                                              84.8223
# CF                                                                                      58.3043
# EI_rating                                                                               32.2585
#
#                                                                                           run97  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6290.86
# dwelling_CO2_emission_rate                                                              63.5826
# CF                                                                                      43.7048
# EI_rating                                                                               44.1498
#
#                                                                                           run98  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8208.58
# dwelling_CO2_emission_rate                                                              82.9652
# CF                                                                                      57.0278
# EI_rating                                                                               33.1718
#
#                                                                                           run99  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6857.58
# dwelling_CO2_emission_rate                                                              69.3105
# CF                                                                                      47.6419
# EI_rating                                                                                40.591
#
#                                                                                          run100
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6636.92
# dwelling_CO2_emission_rate                                                              67.0802
# CF                                                                                      46.1089
# EI_rating                                                                               41.9404
#
# [192 rows x 100 columns]

# %%
total_energy_used=[v['total_energy_used'] for v in outputs.values()]
total_energy_used
# Out:
# [35290.556457758175,
#  33262.93358474502,
#  32091.31807009558,
#  39021.730563855475,
#  30741.36478047183,
#  32749.988248004378,
#  30244.73893767293,
#  37905.84165978988,
#  34667.33302267214,
#  33329.702965551965,
#  37986.203064207235,
#  28798.845633280514,
#  33513.78825269273,
#  36669.17039656631,
#  38328.942000115814,
#  40016.93192706453,
#  30851.221787628845,
#  32473.80143706472,
#  30288.38269351395,
#  38557.89021020434,
#  37647.02821312794,
#  28327.238279594345,
#  36781.337730431245,
#  31215.37040186028,
#  38543.480231838774,
#  40069.68845986717,
#  37922.277537741975,
#  29265.327339840318,
#  36779.98783571171,
#  27613.65355476152,
#  37688.11475707295,
#  30512.829855047035,
#  35794.62284530604,
#  31504.522904399833,
#  36986.16770633398,
#  35480.1402308812,
#  37146.966151823835,
#  28694.61524149555,
#  31394.987159858767,
#  33911.36250409982,
#  28775.304763809367,
#  37957.13103543513,
#  39307.036005671434,
#  30750.985214274737,
#  32075.17403263287,
#  28595.34754527582,
#  38930.20678599236,
#  34094.53510812873,
#  34474.719016858355,
#  32765.48917303252,
#  30300.621120676104,
#  32697.012941591584,
#  28804.6727647209,
#  35641.161878474406,
#  30016.847605468796,
#  31766.804060269944,
#  35265.51628582033,
#  36012.000104330546,
#  37935.636738028246,
#  34881.64860370609,
#  31649.797403219247,
#  37386.23885942704,
#  33640.84862143218,
#  28110.076924381105,
#  31183.400219351093,
#  35156.8623983017,
#  36598.352179525515,
#  36232.108428657506,
#  32440.174319524318,
#  34561.669376207064,
#  35486.61859221586,
#  39440.88602252896,
#  28448.912758570557,
#  39807.72435140694,
#  34640.55482033972,
#  38854.594765401416,
#  27638.648629021074,
#  32694.75761398577,
#  34468.74722991459,
#  27339.42038888781,
#  30274.698209358943,
#  33338.91730807941,
#  36348.84261912339,
#  29178.188213658505,
#  28665.28358588219,
#  32009.535964093935,
#  34665.32812181356,
#  31155.639076210588,
#  38754.48880584516,
#  31090.306592989953,
#  34904.10858430609,
#  40409.79889832899,
#  35430.98789361712,
#  36484.77681112051,
#  34630.1011050071,
#  38666.319750668,
#  28999.420057635274,
#  37836.347373102624,
#  31600.614826275927,
#  30604.412809615358]

# %%
total_CO2_emissions_yearlys=[v['total_CO2_emissions_yearly'] for v in outputs.values()]
total_CO2_emissions_yearlys
# Out:
# [7648.722399820569,
#  7204.684345656662,
#  6961.136516150146,
#  8468.100109833944,
#  6659.193380072366,
#  7099.8317229877675,
#  6551.189939346863,
#  8221.793652576675,
#  7529.186784676824,
#  7233.294134428088,
#  8228.728427082893,
#  6247.193112022385,
#  7261.953273606363,
#  7941.271449583487,
#  8317.042633918962,
#  8674.982149216203,
#  6691.841961681416,
#  7049.514142638884,
#  6580.354150874219,
#  8348.357872947048,
#  8154.343429054998,
#  6156.2138690163665,
#  7971.382346602756,
#  6777.727884275648,
#  8357.806835871565,
#  8683.119606760341,
#  8225.617042142816,
#  6352.319442079437,
#  7971.436443002552,
#  5985.846607406056,
#  8159.656568762623,
#  6619.93947412807,
#  7755.393536838805,
#  6837.369051416635,
#  8014.670921127675,
#  7690.3288579025175,
#  8060.10249668498,
#  6216.319651954256,
#  6820.212316203962,
#  7362.925078853628,
#  6245.954967677244,
#  8230.322425554312,
#  8517.290047217912,
#  6681.339876809773,
#  6947.64863348299,
#  6205.252753499733,
#  8435.7589818294,
#  7402.762830157917,
#  7467.59078888926,
#  7103.999191427433,
#  6563.94077297821,
#  7100.55275012476,
#  6253.742810851721,
#  7724.445320097148,
#  6510.331049377934,
#  6883.852180146679,
#  7641.600920511852,
#  7805.439262207709,
#  8232.790637330687,
#  7567.907329993582,
#  6862.2861907398055,
#  8108.344151907796,
#  7304.687105896633,
#  6090.974491726906,
#  6763.417336589818,
#  7617.434990137524,
#  7943.473812213373,
#  7859.267760944791,
#  7038.636297417401,
#  7483.048089588068,
#  7696.929049635866,
#  8538.544655321253,
#  6168.040418414354,
#  8635.16479018642,
#  7502.945815389918,
#  8426.428487447363,
#  6002.4157259807935,
#  7081.750684178486,
#  7482.076480046089,
#  5930.917751303677,
#  6569.925055212126,
#  7233.8296207742205,
#  7889.57156519024,
#  6321.609127667434,
#  6216.207523192293,
#  6945.203263211777,
#  7507.843073202653,
#  6764.501364176782,
#  8401.416121460083,
#  6738.599146075622,
#  7558.629176298108,
#  8747.119578262971,
#  7690.401499096472,
#  7904.60161833904,
#  7521.148333284886,
#  8392.314853896742,
#  6290.864682225222,
#  8208.579713870879,
#  6857.581466495684,
#  6636.918761686494]

# %%
output = pd.DataFrame(outputs)
output
# Out:
#                                                                                            run1  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7648.72
# dwelling_CO2_emission_rate                                                              77.3067
# CF                                                                                      53.1383
# EI_rating                                                                               36.0863
#
#                                                                                            run2  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7204.68
# dwelling_CO2_emission_rate                                                              72.8187
# CF                                                                                      50.0534
# EI_rating                                                                               38.5538
#
#                                                                                            run3  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6961.14
# dwelling_CO2_emission_rate                                                              70.3572
# CF                                                                                      48.3614
# EI_rating                                                                               39.9726
#
#                                                                                            run4  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                               8468.1
# dwelling_CO2_emission_rate                                                              85.5882
# CF                                                                                      58.8308
# EI_rating                                                                               31.8876
#
#                                                                                            run5  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6659.19
# dwelling_CO2_emission_rate                                                              67.3054
# CF                                                                                      46.2637
# EI_rating                                                                               41.8022
#
#                                                                                            run6  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7099.83
# dwelling_CO2_emission_rate                                                               71.759
# CF                                                                                      49.3249
# EI_rating                                                                               39.1587
#
#                                                                                            run7  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6551.19
# dwelling_CO2_emission_rate                                                              66.2138
# CF                                                                                      45.5133
# EI_rating                                                                               42.4768
#
#                                                                                            run8  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8221.79
# dwelling_CO2_emission_rate                                                              83.0988
# CF                                                                                      57.1196
# EI_rating                                                                               33.1054
#
#                                                                                            run9  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7529.19
# dwelling_CO2_emission_rate                                                              76.0985
# CF                                                                                      52.3078
# EI_rating                                                                               36.7362
#
#                                                                                           run10  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7233.29
# dwelling_CO2_emission_rate                                                              73.1079
# CF                                                                                      50.2521
# EI_rating                                                                               38.3903
#
#                                                     ...  \
# volume                                              ...
# total_floor_area                                    ...
# dwelling_volume                                     ...
# number_of_chimneys_total                            ...
# number_of_chimneys_m3_per_hour                      ...
# ...                                                 ...
# energy_saving_generation_technologies_total_emi...  ...
# total_CO2_emissions_yearly                          ...
# dwelling_CO2_emission_rate                          ...
# CF                                                  ...
# EI_rating                                           ...
#
#                                                                                           run91  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7558.63
# dwelling_CO2_emission_rate                                                              76.3961
# CF                                                                                      52.5124
# EI_rating                                                                               36.5752
#
#                                                                                           run92  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8747.12
# dwelling_CO2_emission_rate                                                              88.4083
# CF                                                                                      60.7692
# EI_rating                                                                               30.5501
#
#                                                                                           run93  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                               7690.4
# dwelling_CO2_emission_rate                                                              77.7279
# CF                                                                                      53.4278
# EI_rating                                                                               35.8621
#
#                                                                                           run94  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                               7904.6
# dwelling_CO2_emission_rate                                                              79.8929
# CF                                                                                      54.9159
# EI_rating                                                                               34.7286
#
#                                                                                           run95  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              7521.15
# dwelling_CO2_emission_rate                                                              76.0173
# CF                                                                                       52.252
# EI_rating                                                                               36.7802
#
#                                                                                           run96  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8392.31
# dwelling_CO2_emission_rate                                                              84.8223
# CF                                                                                      58.3043
# EI_rating                                                                               32.2585
#
#                                                                                           run97  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6290.86
# dwelling_CO2_emission_rate                                                              63.5826
# CF                                                                                      43.7048
# EI_rating                                                                               44.1498
#
#                                                                                           run98  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              8208.58
# dwelling_CO2_emission_rate                                                              82.9652
# CF                                                                                      57.0278
# EI_rating                                                                               33.1718
#
#                                                                                           run99  \
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6857.58
# dwelling_CO2_emission_rate                                                              69.3105
# CF                                                                                      47.6419
# EI_rating                                                                                40.591
#
#                                                                                          run100
# volume                                              [0, 114.88499999999999, 112.67699999999999]
# total_floor_area                                                                          98.94
# dwelling_volume                                                                         227.562
# number_of_chimneys_total                                                                      0
# number_of_chimneys_m3_per_hour                                                                0
# ...                                                                                         ...
# energy_saving_generation_technologies_total_emi...                                            0
# total_CO2_emissions_yearly                                                              6636.92
# dwelling_CO2_emission_rate                                                              67.0802
# CF                                                                                      46.1089
# EI_rating                                                                               41.9404
#
# [192 rows x 100 columns]

# %%
output.run3['total_energy_used']
# Out:
# 32091.31807009558

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Example')
ax1.boxplot(total_energy_used)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e923186f88>,
#   <matplotlib.lines.Line2D at 0x1e923186c08>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e92318fe88>,
#   <matplotlib.lines.Line2D at 0x1e92318ff88>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e923186988>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e923193b08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e923193f88>],
#  'means': []}

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Example')
sns.distplot(total_energy_used,hist=False)

# %%
sp='input_csv_file_high_ins.csv'
s.read_input_csv(sp)

# %%
outputs_1={} 
total_energy_used_table_1 = {}
for k in range(100):
    value_min_1 = []
    value_max_1 = []
    values_1 = []
    for i in range(len(index_name)):
        values_1.append(s.inputs[index_name[i]])
        if (type(values_1[i])==list):
            calc_list_min_1 = np.array(values_1[i])
            value_min_1.append(calc_list_min_1 - 0.1 * calc_list_min_1)
            calc_list_max_1 = np.array(values_1[i])
            value_max_1.append(calc_list_max_1 + 0.1 * calc_list_max_1)
        else:
            value_min_1.append(values_1[i] - 0.1 * values_1[i])
            value_max_1.append(values_1[i] + 0.1 * values_1[i])
        s.inputs[index_name[i]] = random.uniform(value_min_1[i],value_max_1[i])
        
    s.run()
    total_energy_used_1 = ([v['total_energy_used'] for v in outputs_1.values()])
    total_energy_used_table_1[k]=total_energy_used_1
    outputs_1['run%s' % str(k+1)]=s.outputs.copy()# needs copy otherwise the same object is placed in all dictionary items
    s.read_input_csv(sp)  
    output_table_1 = pd.DataFrame(outputs)

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Example')
sns.distplot(total_energy_used_1,hist=False)

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Occupant Behaviour')
ax1.boxplot([total_energy_used,total_energy_used_1])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e923a5e788>,
#   <matplotlib.lines.Line2D at 0x1e923a6ef88>,
#   <matplotlib.lines.Line2D at 0x1e923a78f48>,
#   <matplotlib.lines.Line2D at 0x1e923a78c48>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e923a6eb88>,
#   <matplotlib.lines.Line2D at 0x1e923a72a88>,
#   <matplotlib.lines.Line2D at 0x1e923a81b48>,
#   <matplotlib.lines.Line2D at 0x1e923a81f48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e923a6e348>,
#   <matplotlib.lines.Line2D at 0x1e923811148>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e923a56848>,
#   <matplotlib.lines.Line2D at 0x1e923a81cc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e923a72c08>,
#   <matplotlib.lines.Line2D at 0x1e923a8ab48>],
#  'means': []}

# %%
writer = pd.ExcelWriter('monte_carlo.xlsx',engine = 'xlsxwriter')

# %%
total_energy_used.to_excel(writer,sheet_name = 'low_ins')
total_energy_used_1.to_excel(writer,sheet_name = 'high_ins')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-afc1dc5bb330> in <module>
# ----> 1 total_energy_used.to_excel(writer,sheet_name = 'low_ins')
#       2 total_energy_used_1.to_excel(writer,sheet_name = 'high_ins')
#
# AttributeError: 'list' object has no attribute 'to_excel'
